# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-53675104-6825-472b-9aa5-4741aa3df167" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53675104-6825-472b-9aa5-4741aa3df167">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# El dataset presentado reúne información académica correspondiente a cinco
# generaciones de estudiantes (2017, 2018, 2019, 2020 y 2023) del Instituto Regional del Maule, ubicado en la comuna de San Javier. Los datos consideran el porcentaje de asistencia y el rendimiento escolar desde primero a septimo básico, organizados por asignatura y nivel.
#
# No se econsideraron las generaciones 2021 y 2022 debido a la pandemia.
#
# Con el fin de proteger la identidad de los estudiantes, estos han sido identificados mediante su fecha de nacimiento, sin incluir nombres ni RUT.
#
# Una característica importante del establecimiento es que, al finalizar sexto básico, realiza una clasificación de los estudiantes en dos niveles para cursar séptimo básico: Avanzado y No avanzado.
#
# Para determinar el nivel de los estudiante se basan en el rendimiento académico obtenido en las asignaturas cientifico humanista de sexto básico.
#
# La clasificacion se encuentra registrada en la columna denominada Nivel 7

# %%
import pandas as pd
df = pd.read_csv('01database.csv', sep=';', decimal=',')
df.head(10)
# Out:
#    Generacion    Fec.Nac.  Lenguaje 1  Ingles 1  Matematica 1  C Naturales 1  \
# 0        2017  21-06-2003         5.7       6.2           6.4            6.0
# 1        2017  02-08-2003         NaN       NaN           NaN            NaN
# 2        2017  06-08-2003         NaN       NaN           NaN            NaN
# 3        2017  10-10-2003         NaN       NaN           NaN            NaN
# 4        2017  18-12-2003         5.0       5.4           5.6            6.0
# 5        2017  27-03-2004         NaN       NaN           NaN            NaN
# 6        2017  01-04-2004         4.0       5.7           5.5            5.2
# 7        2017  26-04-2004         6.5       5.9           6.7            6.2
# 8        2017  03-05-2004         5.4       6.6           6.5            6.1
# 9        2017  09-06-2004         NaN       NaN           NaN            NaN
#
#    Historia 1  Tecnologia 1  E Artistica 1  E Fisica 1  ...  Matematica 7  \
# ...

# %%
# Estadísticas descriptivas
df.describe()
# Out:
#         Generacion  Lenguaje 1    Ingles 1  Matematica 1  C Naturales 1  \
# count   418.000000  321.000000  321.000000    321.000000     321.000000
# mean   2019.413876    5.981931    6.354206      5.978193       6.239252
# std       2.004431    0.817724    0.585066      0.683528       0.516495
# min    2017.000000    2.000000    3.500000      3.500000       3.700000
# 25%    2018.000000    5.700000    6.100000      5.700000       5.900000
# 50%    2019.000000    6.200000    6.500000      6.100000       6.400000
# 75%    2020.000000    6.500000    6.800000      6.500000       6.600000
# max    2023.000000    7.000000    7.000000      7.000000       7.000000
#
#        Historia 1  Tecnologia 1  E Artistica 1  E Fisica 1      Prom 1  ...  \
# count  321.000000    321.000000     321.000000  321.000000  321.000000  ...
# mean     6.149844      6.631776       6.582243    6.751713    6.344548  ...
# std      0.592301      0.350695       0.339157    0.280633    0.418378  ...
# ...

# %%
# Exploración y Análisis de los Datos
# Dimensiones del dataset
print(f"Dimensiones del dataset: {df.shape}")

# Tipos de datos y valores nulos
df.info()
# Out:
# Dimensiones del dataset: (418, 86)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 86 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Generacion                418 non-null    int64
#  1   Fec.Nac.                  418 non-null    object
#  2   Lenguaje 1                321 non-null    float64
#  3   Ingles 1                  321 non-null    float64
#  4   Matematica 1              321 non-null    float64
#  5   C Naturales 1             321 non-null    float64
#  6   Historia 1                321 non-null    float64
#  7   Tecnologia 1              321 non-null    float64
#  8   E Artistica 1             321 non-null    float64
#  9   E Fisica 1                321 non-null    float64
#  10  Prom 1                    321 non-null    float64
#  11  % 1                       321 non-null    float64
#  12  Lenguaje 2                315 non-null    float64
# ...
